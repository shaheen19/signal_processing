# %% [markdown]
# ## Project 1B: BC (microg/m3) Multilevel Discrete Wavelet Transform of 1D Time Series

# %% [markdown]
# ### Project Objective
# Identify vehicles releasing pollutants, Black Carbon, oxides of nitrogen and GHG (CO2)
# #### Use Disrete Wavelet transform and 1D time series to denoise the signal
# - Make multilevel decomposition
# - Visualize the Approximation and Details coeffcients
# - Reconstruct orignal time series signal
# - Reconstruct the Approximation and Details
# - Visualize the Approximation and Details
# - reduce data noise at different levels and visualizae the results

# %% [markdown]
# ### Import required packages

# %%
import os
import glob
import csv
import re

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy import stats
from scipy import signal
import pywt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
import seaborn as sns

# Handle date time conversions between pandas and matplotlib
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
os.getcwd()
# Out:
# 'C:\\Users\\bina_\\Dropbox\\Robina Shaheen_PEMS2022\\PEMS_NOx_BC_CO2_ALPR\\ii.dwt'

# %% [markdown]
# ### Read the data

# %%
# base_path=os.path.join ('ii.dwt','data')
# base_path
df = pd.read_csv('./data/2022-09-02/ma300.csv')
df.head(3)
# Out:
#                          Time Serial Number  Datum ID  Session ID  \
# 0  2022-09-02 00:00:01.856921    MA300-0075  180654.0        19.0
# 1  2022-09-02 00:00:02.836060    MA300-0075  180655.0        19.0
# 2  2022-09-02 00:00:03.854123    MA300-0075  180656.0        19.0
#
#    Data format version  Firmware Version               Date Time  \
# 0                  1.0               1.1  2022-09-02T07:00:00.00
# 1                  1.0               1.1  2022-09-02T07:00:01.00
# 2                  1.0               1.1  2022-09-02T07:00:02.00
#
#    Timezone offset    GPS Lat    GPS Long  ...  Green BC1  Green BC2  \
# 0           -420.0  33.606471 -114.535798  ...      654.0        NaN
# 1           -420.0  33.606454 -114.535801  ...     1576.0        NaN
# 2           -420.0  33.606450 -114.535808  ...     1038.0        NaN
#
#    Green BCc  Red BC1  Red BC2  Red BCc  IR BC1  IR BC2  IR BCc  CKSUM
# 0        NaN    703.0      NaN      NaN  1213.0     NaN     NaN   50AB
# 1        NaN    756.0      NaN      NaN   889.0     NaN     NaN   5098
# 2        NaN   2207.0      NaN      NaN   522.0     NaN     NaN   5110
#
# [3 rows x 74 columns]

# %%
print(df.columns)
print(df.shape)
df = df.ffill().bfill()
#df.info()
# Out:
# Index(['Time', 'Serial Number', 'Datum ID', 'Session ID',
#        'Data format version', 'Firmware Version', 'Date Time',
#        'Timezone offset', 'GPS Lat', 'GPS Long', 'GPS Speed', 'Timebase',
#        'Status', 'Battery', 'Accel X', 'Accel Y', 'Accel Z', 'Tape Position',
#        'Flow Set', 'Flow Total', 'Flow 1', 'Flow 2', 'Air Temp', 'Air RH',
#        'Air DP', 'Int Pr', 'Int Temp', 'Optical config', 'UV Sen1', 'UV Sen2',
#        'UV Ref', 'UV ATN1', 'UV ATN2', 'UV K', 'Blue Sen1', 'Blue Sen2',
#        'Blue Ref', 'Blue ATN1', 'Blue ATN2', 'Blue K', 'Green Sen1',
#        'Green Sen2', 'Green Ref', 'Green ATN1', 'Green ATN2', 'Green K',
#        'Red Sen1', 'Red Sen2', 'Red Ref', 'Red ATN1', 'Red ATN2', 'Red K',
#        'IR Sen1', 'IR Sen2', 'IR Ref', 'IR ATN1', 'IR ATN2', 'IR K', 'UV BC1',
#        'UV BC2', 'UV BCc', 'Blue BC1', 'Blue BC2', 'Blue BCc', 'Green BC1',
#        'Green BC2', 'Green BCc', 'Red BC1', 'Red BC2', 'Red BCc', 'IR BC1',
#        'IR BC2', 'IR BCc', 'CKSUM'],
#       dtype='object')
# (71476, 74)

# %%
print('Empty cells/ zero values:', df.isnull().sum())
# Out:
# Empty cells/ zero values: Time                       0
# Serial Number              0
# Datum ID                   0
# Session ID                 0
# Data format version        0
#                        ...
# Red BCc                71476
# IR BC1                     0
# IR BC2                 71476
# IR BCc                 71476
# CKSUM                      0
# Length: 74, dtype: int64

# %% [markdown]
# ### Transform and select  BC Data

# %%
df['time2'] = df['Time'].astype(str).str.split().str[1]
# df['time2'] = df['Time'].dt.strftime('%H:%M:%S')
df.tail(3)
# Out:
#                              Time Serial Number  Datum ID  Session ID  \
# 71473  2022-09-02 23:59:58.555425    MA300-0075  267035.0        19.0
# 71474  2022-09-02 23:59:59.555325    MA300-0075  267036.0        19.0
# 71475  2022-09-03 00:00:00.555224    MA300-0075  267037.0        19.0
#
#        Data format version  Firmware Version               Date Time  \
# 71473                  1.0               1.1  2022-09-03T06:59:56.00
# 71474                  1.0               1.1  2022-09-03T06:59:57.00
# 71475                  1.0               1.1  2022-09-03T06:59:58.00
#
#        Timezone offset    GPS Lat    GPS Long  ...  Green BC2  Green BCc  \
# 71473           -420.0  33.606223 -114.535750  ...        NaN        NaN
# 71474           -420.0  33.606218 -114.535751  ...        NaN        NaN
# 71475           -420.0  33.606216 -114.535746  ...        NaN        NaN
#
#        Red BC1  Red BC2  Red BCc  IR BC1  IR BC2  IR BCc  CKSUM  \
# 71473    854.0      NaN      NaN   294.0     NaN     NaN   509C
# 71474     25.0      NaN      NaN   796.0     NaN     NaN   5054
# 71475    880.0      NaN      NaN   195.0     NaN     NaN   5044
#
#                  time2
# 71473  23:59:58.555425
# 71474  23:59:59.555325
# 71475  00:00:00.555224
#
# [3 rows x 75 columns]

# %%
df["IR BC1_ug"] = df["IR BC1"]/ 1000+1
df.head(3)
# Out:
#                          Time Serial Number  Datum ID  Session ID  \
# 0  2022-09-02 00:00:01.856921    MA300-0075  180654.0        19.0
# 1  2022-09-02 00:00:02.836060    MA300-0075  180655.0        19.0
# 2  2022-09-02 00:00:03.854123    MA300-0075  180656.0        19.0
#
#    Data format version  Firmware Version               Date Time  \
# 0                  1.0               1.1  2022-09-02T07:00:00.00
# 1                  1.0               1.1  2022-09-02T07:00:01.00
# 2                  1.0               1.1  2022-09-02T07:00:02.00
#
#    Timezone offset    GPS Lat    GPS Long  ...  Green BCc  Red BC1  Red BC2  \
# 0           -420.0  33.606471 -114.535798  ...        NaN    703.0      NaN
# 1           -420.0  33.606454 -114.535801  ...        NaN    756.0      NaN
# 2           -420.0  33.606450 -114.535808  ...        NaN   2207.0      NaN
#
#    Red BCc  IR BC1  IR BC2  IR BCc  CKSUM            time2  IR BC1_ug
# 0      NaN  1213.0     NaN     NaN   50AB  00:00:01.856921      2.213
# 1      NaN   889.0     NaN     NaN   5098  00:00:02.836060      1.889
# 2      NaN   522.0     NaN     NaN   5110  00:00:03.854123      1.522
#
# [3 rows x 76 columns]

# %%
df2 = pd.DataFrame(df,
                  columns=['time2', 'IR BC1_ug'])
df2.head(3)
# Out:
#              time2  IR BC1_ug
# 0  00:00:01.856921      2.213
# 1  00:00:02.836060      1.889
# 2  00:00:03.854123      1.522

# %%
# df2 = pd.DataFrame(df,
#                   columns=['time2', 'IR BC1_ug'])
# from brokenaxes import brokenaxes
fig = plt.figure(figsize=(5, 2))
# bax = brokenaxes(xlims=((-1, 1), (1, 40), (50,300)), 
#                  ylims=((0, 10), (50, 100)), hspace=.05)
# x = np.linspace(0, 1, 100)
# bax.plot(x, np.sin(10 * x), label='sin')
# x= df2['IR_BC1_ug']
# bax.plot(x,  label='cos')
# bax.legend()
# bax.set_xlabel('BC')
# bax.set_ylabel('Frequency')
# # Import seaborn
# import seaborn as sns
# sns.displot(data=df2, x="total_bill", col="time", kde=True)
# Plot Histogram on x
# plt.rcParams["figure.figsize"] = (6, 4)
# df2 = pd.DataFrame(df,
#                   columns=['Time', 'IR BC1'])
# df2["IR_BC1_ug"] = df["IR BC1"] / 1000
# df2.head()
x= df2['IR BC1_ug']
plt.hist(x, bins = 1000)
plt.gca().set(title='BC signal frequency Histogram', 
              xlabel= 'BC (ug/m3)', ylabel='Frequency');

# %%
# import scipy
# from scipy import stats

# %%
# observation_x = df2['IR BC1_ug']
# histogram, bins = scipy.histogram(['observation_x'],
# bins = range(4))
# print ("Number of values in each bin : ", histogram)
# print ("Size of the bins          : ", bins)

# CDF_norm = stats.norm.CDF(observatin_x,loc=0,scale=1)

# %%
# plt.plot(observatin_x,CDF_norm)
# plt.xlabel('x-values')
# plt.ylabel('CDF_norm_values')
# plt.title("Comulative distribution function")
# plt.show()

# %%
# set plot size for the plot
# plt.rcParams["date.autoformatter.minute"] = "%H:%M:%S"
# fig, (ax) = plt.subplots(constrained_layout=True)
# yticks = np.arange(-50, 300, 50)
# yrange = (yticks[0], yticks[-1])
# xticks = np.arange(0, 8000, 1000)
plt.rcParams["figure.figsize"] = (10, 6)
offset = -.03
# df2 = pd.DataFrame(df,
#                   columns=['Time', 'IR BC1_ug'])

df2.plot(x='time2', y='IR BC1_ug',color="black")

# plt.setp(ax.get_xticklabels(), rotation=45)
# Define the date format
# format your data to desired format. 

#import matplotlib.dates as mdates
# ax = plt.gca()
# ax.axis.set_major_formatter(mdates.DateFormatter('%H-%M-%S'))
# date_form = DateFormatter("%H-%M:%S")
# ax.axis.set_major_formatter(date_form)
plt.xticks(rotation = 45) # Rotates X-Axis Ticks by 45-degrees
# fig.autofmt_xdate()
plt.ylabel('BC (ug/m3)')
plt.xlabel('Time (ms)')
plt.title("BC (ug/m3)with PEMS instrument", fontsize=14)
plt.show()

# %% [markdown]
# ### Slice  data for wavelet transformations

# %%
# t = df2['time2'].astype('datetime64[s]')

t = df2['time2']
s = df2['IR BC1_ug']
print(type(t))
print(len(t))
print(t.head(3))
print(t.tail(3))
# Out:
# <class 'pandas.core.series.Series'>
# 71476
# 0    00:00:01.856921
# 1    00:00:02.836060
# 2    00:00:03.854123
# Name: time2, dtype: object
# 71473    23:59:58.555425
# 71474    23:59:59.555325
# 71475    00:00:00.555224
# Name: time2, dtype: object

# %% [markdown]
# ### (4) Plot the signal

# %%
fig,ax = plt.subplots(figsize=(15,7))

plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)

# ax.plot(t,s)
# Add x-axis and y-axis
ax.plot(df2.index.values,
       df2['IR BC1_ug'],
       color='purple')
ax.set_xlabel('t (ms)',fontsize=15)
ax.set_ylabel('BC (ug/m3)',fontsize=15)

plt.savefig('./results/BC_ug_PEMS.png',dpi=300)
plt.show()

# %% [markdown]
# ## 4. Perform Multi-level Wavelet Decomposition

# %% [markdown]
# ### (1) Maximum decomposition level

# %%
w = pywt.Wavelet('db6')
l = len(s)
f_l = w.dec_len

max_l = pywt.dwt_max_level(data_len=l, filter_len=f_l)

print(max_l)
# Out:
# 12

# %% [markdown]
# ### (2) Wavelet decomposition

# %%
coeffs = pywt.wavedec(s,'db6','sym',level=6)

(cA6,cD6,cD5,cD4,cD3,cD2,cD1) = coeffs

# %% [markdown]
# ### (3) Print the approximation and detail coefficients

# %%
print('cA6 = ',cA6)
print('cD6 = ',cD6)
# Out:
# cA6 =  [18.41214711 18.32779113 18.34299683 ... 21.20987432 31.43566052
#   8.79133418]
# cD6 =  [-3.65599426e-02 -5.16085000e-04 -2.27489883e-01 ...  2.90468032e+00
#  -3.90353862e+00 -8.51287344e-01]

# %% [markdown]
# ### (3) length of the coefficients

# %%
print(len(s))
print(len(cA6))
print(len(cD6))
# Out:
# 71476
# 1127
# 1127

# %% [markdown]
# ## 5. Visualization of  Approximation and Details Coefficients

# %%
fig,axs = plt.subplots(4,2,figsize=(15,12))

plt.rc('xtick',labelsize=12)
plt.rc('ytick',labelsize=12)

axs[0,0].plot(s)
axs[0,0].set_ylabel('s (BC)',fontsize=13)

axs[0,1].plot(cA6)
axs[0,1].set_ylabel('cA6',fontsize=13)

axs[1,0].plot(cD6)
axs[1,0].set_ylabel('cD6',fontsize=13)

axs[1,1].plot(cD5)
axs[1,1].set_ylabel('cD5',fontsize=13)

axs[2,0].plot(cD4)
axs[2,0].set_ylabel('cD4',fontsize=13)

axs[2,1].plot(cD3)
axs[2,1].set_ylabel('cD3',fontsize=13)

axs[3,0].plot(cD2)
axs[3,0].set_ylabel('cD2',fontsize=13)
axs[3,0].set_xlabel('t (ms)',fontsize=13)

axs[3,1].plot(cD1)
axs[3,1].set_ylabel('cD1',fontsize=13)
axs[3,1].set_xlabel('t (ms)',fontsize=13)

plt.tight_layout()
plt.savefig('./results/BC_ug_s_coeffs.png',dpi=300)

plt.show()

# %% [markdown]
# ## 6. Reconstruct the Signal

# %%
s_r = pywt.waverec(coeffs,'db6','sym')
s_r
# Out:
# array([2.213, 1.889, 1.522, ..., 1.294, 1.796, 1.195])

# %%
df3= pd.DataFrame(s_r,columns=['recon_s'] )
# df3
# df3.rename(columns={'0':'s_r'}, inplace=True)
df3
# combined_sig = pd.concat([df3, df2])
# combined_sig
# Out:
#        recon_s
# 0        2.213
# 1        1.889
# 2        1.522
# 3        2.548
# 4        2.735
# ...        ...
# 71471    4.012
# 71472    3.634
# 71473    1.294
# 71474    1.796
# 71475    1.195
#
# [71476 rows x 1 columns]

# %%
print(len(s))
print(len(s_r))
# Out:
# 71476
# 71476

# %% [markdown]
# ### (2) reconstructed signal

# %%
# # errors

# err = sum(s-s_r)/len(s)
# max_err = max(abs(s-s_r))

# print(err)
# print(max_err)

# %%
# s_r = s_r[:-1]

# %% [markdown]
# ### (3) Comparing reconstructed signal with the original one

# %%
# plot
fig,(ax1,ax2) = plt.subplots(2,1, sharex= True, figsize=(12,6))
# Add x-axis and y-axis
ax1.plot(df3.index.values,
       df3['recon_s'],
       color='green')
ax2.plot(df.index.values,
       df['IR BC1'],
       color='purple')
ax2.set(
    ylabel="IR BC1 (ng/m3)",
    title="BC origninal signal")
ax1.set(#xlabel = "Time (ms)",
    ylabel=" BC (ug/m3)",
    title=" Reconstructed signal")
# ax.plot(t,s)
# ax.plot(t,s_r)

plt.show()

# %% [markdown]
# ## 7. Reconstruct Approximations and Details

# %% [markdown]
# ### (1) Create zero arrays

# %%
cA06 = np.zeros(len(cA6))
cD06 = np.zeros(len(cD6))
cD05 = np.zeros(len(cD5))
cD04 = np.zeros(len(cD4))
cD03 = np.zeros(len(cD3))
cD02 = np.zeros(len(cD2))
cD01 = np.zeros(len(cD1))

# %%
print(cA06)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %% [markdown]
# ### (2) Reconstruct Approximations and Details

# %%
A6 = pywt.waverec((cA6,cD06,cD05,cD04,cD03,cD02,cD01),'db6','sym')
D6 = pywt.waverec((cA06,cD6,cD05,cD04,cD03,cD02,cD01),'db6','sym')
D5 = pywt.waverec((cA06,cD06,cD5,cD04,cD03,cD02,cD01),'db6','sym')
D4 = pywt.waverec((cA06,cD06,cD05,cD4,cD03,cD02,cD01),'db6','sym')
D3 = pywt.waverec((cA06,cD06,cD05,cD04,cD3,cD02,cD01),'db6','sym')
D2 = pywt.waverec((cA06,cD06,cD05,cD04,cD03,cD2,cD01),'db6','sym')
D1 = pywt.waverec((cA06,cD06,cD05,cD04,cD03,cD02,cD1),'db6','sym')

# %%
# check the length

print(len(s))
print(len(A6))
# Out:
# 71476
# 71476

# %%
# A6 = A6[:-1]
# D6 = D6[:-1]
# D5 = D5[:-1]
# D4 = D4[:-1]
# D3 = D3[:-1]
# D2 = D2[:-1]
# D1 = D1[:-1]

# %% [markdown]
# ### (3) Approximations at other levels

# %%
A5 = A6 + D6 
A4 = A6 + D6 + D5
A3 = A6 + D6 + D5 + D4
A2 = A6 + D6 + D5 + D4 + D3
A1 = A6 + D6 + D5 + D4 + D3 + D2

# %% [markdown]
# ### (4) Reconstruct signal from approximation and details

# %%
s_r = A6 + D6 + D5 + D4 + D3 + D2 + D1

# %%
app6= pd.DataFrame(A6,columns=['Approx_6'] )
app6
df6_s = app6[['Approx_6']].agg(['min','max', 'mean'])
print (df6_s)
# Out:
#        Approx_6
# min  -12.543724
# max   54.082820
# mean   2.612569

# %%
# Reconstructed signal from approximation
app3= pd.DataFrame(A3,columns=['Approx_3'] )
app3
arr3 = app3.to_numpy()
arr3
# arr3.dtype
# app2= pd.DataFrame(A2,columns=['Approx_2'] )
# app2
df3_s = app3[['Approx_3']].agg(['min','max', 'mean'])
print (df3_s)
# Out:
#         Approx_3
# min   -20.983127
# max   241.265784
# mean    2.612998

# %%
# app3= pd.DataFrame(A3,columns=['Approx_3'] )
# app3
# combined_df= [app6, t]
recon_s_t= pd.concat([app3, t], axis = 1)
# recon_s_t['time'] = recon_s_t['time2'].astype('datetime64[s]')

# app3.to_csv('./data/IR_BC1_ug_denoised_signal.csv',index=False)
recon_s_t.to_csv('./data/IR_BC1_ug_denoised_recon_s3_t.csv',index=False)
recon_s_t.head()
# df_s = recon_s_t[['Approx_3']].agg(['min','max'])
# print (df_s)
# Out:
#    Approx_3            time2
# 0  2.172161  00:00:01.856921
# 1  2.277492  00:00:02.836060
# 2  2.403230  00:00:03.854123
# 3  2.530503  00:00:04.823282
# 4  2.641581  00:00:05.836354

# %%
# take slice of data
s3= recon_s_t[:4000]
print(len(s3))
print(s3.head(3))
s3.tail(3)
# Out:
# 4000
#    Approx_3            time2
# 0  2.172161  00:00:01.856921
# 1  2.277492  00:00:02.836060
# 2  2.403230  00:00:03.854123
#       Approx_3            time2
# 3997  1.478935  01:07:43.439169
# 3998  1.493766  01:07:44.416811
# 3999  1.491626  01:07:45.421212

# %%
df_s3 = s3[['Approx_3']].agg(['min','max', 'mean'])
print (df_s3)
# Out:
#        Approx_3
# min    0.240741
# max   12.299094
# mean   1.754939

# %%
#convert DF to array
#peak_time2=s3["time2"].astype('datetime64[s]') ## to remove ms
peak_time2=s3["time2"].values
print(peak_time2)
# peak_date=recon_s_t["time"].values
# print(peak_date)
peak_ss3=s3["Approx_3"].values
peak_ss3
# Out:
# ['00:00:01.856921' '00:00:02.836060' '00:00:03.854123' ...
#  '01:07:43.439169' '01:07:44.416811' '01:07:45.421212']
# array([2.17216081, 2.27749165, 2.40322988, ..., 1.47893481, 1.49376614,
#        1.49162614])

# %%
df_s = recon_s_t[['Approx_3']].agg(['min','max', 'mean'])
print (df_s)
# Out:
#         Approx_3
# min   -20.983127
# max   241.265784
# mean    2.612998

# %%
#convert DF to array
peak_date2=recon_s_t["time2"].values
print(peak_date2)
# peak_date=recon_s_t["time"].values
# print(peak_date)
peak_sig2=recon_s_t["Approx_3"].values
peak_sig2
# Out:
# ['00:00:01.856921' '00:00:02.836060' '00:00:03.854123' ...
#  '23:59:58.555425' '23:59:59.555325' '00:00:00.555224']
# array([2.17216081, 2.27749165, 2.40322988, ..., 2.14113299, 1.94730786,
#        1.76935346])

# %%
# # errors

# err = sum(s-s_r)/len(s)
# max_err = max(abs(s-s_r))

# print(err)
# print(max_err)

# %% [markdown]
# ## 8. Visualization of Approximation and Details

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, 
                    sharex=True, figsize=(12, 6))
# Add x-axis and y-axis
ax1.plot(df.index.values,
         df['IR BC1_ug'],
         color='purple')
# ax2.plot(app2.index.values,
#        app2['Approx_2'],
#        color='orange')

ax2.plot(app3.index.values,
         app3['Approx_3'],
         color='black')
ax3.plot(app6.index.values,
         app6['Approx_6'],
         color='red')

ax1.set(
    ylabel=" BC",
    title="BC signal")
# ax2.set(ylabel=" App. L2")
ax2.set(ylabel="App. L3")
ax3.set(ylabel="App. L6")

plt.tight_layout()
plt.savefig('./results/BC_ug_denoised_signal_comparison.png')
plt.show()

# %% [markdown]
# ### (1) Reconstruct the approximations

# %%
A5 = A6 + D6 
A4 = A6 + D6 + D5
A3 = A6 + D6 + D5 + D4
A2 = A6 + D6 + D5 + D4 + D3
A1 = A6 + D6 + D5 + D4 + D3 + D2

# %% [markdown]
# ### (2) Check errors

# %%
err = sum(s-A6)/len(s)
print(err)
# Out:
# 0.0004225675393591947

# %% [markdown]
# ### (3) Peak Identification

# %%
import matplotlib.pyplot as plt
# from scipy.misc import electrocardiogram
from scipy.signal import find_peaks

# %%
app6= pd.DataFrame(A6,columns=['Approx_6'] )
app6
arr6 = app6.to_numpy()
arr6
# Out:
# array([[2.31569126],
#        [2.30568238],
#        [2.29502186],
#        ...,
#        [3.60973318],
#        [3.59315255],
#        [3.57524002]])

# %%
array_s= recon_s_t.to_numpy()
array_s
print(len(array_s))
print(len(recon_s_t))
print(recon_s_t.dtypes)
# Out:
# 71476
# 71476
# Approx_3    float64
# time2        object
# dtype: object

# %%
# CO2 diurnal variations 380-500 ppm in arizona and traffic
# Check Scipy package to extract features of peaks
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.find_peaks.html

# %%
# to find data type in numpy arrea
A6.dtype
# to find data type in dataframe
app3.dtypes
array_s.dtype
# Out:
# dtype('O')

# %%
# fig, ax = plt.subplots(figsize=(10, 6))
# x = arr3
# x1=x.flatten()


# peaks, _ = find_peaks(x1, height=10)
# plt.plot(x)
# plt.plot(peaks, array_s[peaks], "x", color = 'red')
# # plt.axhline(350, linestyle='--',color="gray" )
# ax.set(xlabel= "Time",
#     ylabel=" BC (ug/g)",
#     title="BC peak identification after removing instrumental noise")
# plt.show()

# %%
# A5s1=A3[1000:3060]
# A5s1.shape
# x1_array = np.arange(1000,3060)
# # amp1 = 3000
# # sigma1 = 10
# # cen1 = 50
# y1_array= A5s1
# plt.plot(x1_array, y1_array)

# %%
x_array = peak_time2
# amp1 = 3000
# sigma1 = 10
# cen1 = 50
y_array= peak_ss3

# %%
# import math

# def computeTicks (x, step = 5):
#     """
#     Computes domain with given step encompassing series x
#     @ params
#     x    - Required - A list-like object of integers or floats
#     step - Optional - Tick frequency
#     """
#     xMax, xMin = math.ceil(max(x)), math.floor(min(x))
#     dMax, dMin = xMax + abs((xMax % step) - step) + (step if (xMax % step != 0) else 0), xMin - abs((xMin % step))
#     return range(dMin, dMax, step)

# %%
# A3s1=A3[1000:3060]
# A3s1.shape
# x_array = peak_date2
# # amp1 = 3000
# # sigma1 = 10
# # cen1 = 50
# y_array= peak_sig
plt.plot(x_array, y_array)
plt.xticks(rotation =60) # Rotates X-Axis Ticks by 45-degrees
plt.grid(b=True, which='major', color='grey', linestyle='--')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(100))
plt.tight_layout()
plt.savefig('./results/subset_BC_denoised_signal.png')
plt.show()
# Out:
# C:\Users\bina_\Miniconda3\envs\earth-analytics-python\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   # Remove the CWD from sys.path while we load stuff.

# %%
peaks, properties = find_peaks(y_array, prominence=2, width=20)
sig_peaks, _ = signal.find_peaks(y_array)
promin = signal.peak_prominences(y_array, sig_peaks)[0]
print(len(promin))
# promin
plt.plot(promin)
# Out:
# 204

# %%
half_peak_res = signal.peak_widths(y_array, sig_peaks, rel_height = 0.5)
full_peak_res = signal.peak_widths(y_array, sig_peaks, rel_height = 1)


plt.plot(x_array, y_array)
plt.plot(sig_peaks, y_array[sig_peaks], "*", color = 'red')
contur_height = y_array[sig_peaks] - promin
# plt.plot(y_array)
# plt.plot(sig_peaks, y_array[sig_peaks], "*")
plt.vlines(x=sig_peaks, ymin=contur_height, ymax=y_array[sig_peaks], 
           color ='black', linestyle='dotted')
plt.hlines(*half_peak_res[1:], color = 'C12')
plt.hlines(*full_peak_res[1:], color = 'C3')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(100))
plt.xticks(rotation =60)
plt.ylabel('BC (ug/m3)', fontsize= 13)
plt.xlabel('Time (H:M:S)', fontsize = 13)
plt.tight_layout()
plt.savefig('./results/BC_peak_area_time.png', dpi=300)
plt.show()

# %%
# print('Half width of peaks:', half_peak_res[0])
HWpeak = np.asarray(half_peak_res)
HWpeak_BC = pd.DataFrame(HWpeak)
# print(HWpeak_BC.head(3))
HWpeak_BC.to_csv('./results/BC_HWpeak.csv')

# print('Full width of peaks:', full_peak_res[0])
FWpeak = np.asarray(full_peak_res)
FWpeak_BC = pd.DataFrame(FWpeak)
FWpeak_BC.to_csv('./results/BC_FWpeak.csv')
print('Height of peaks:',contur_height)
contur_height_BC = pd.DataFrame(contur_height)
contur_height_BC.to_csv('./results/BC_peak_height.csv')
# contur_height.to_csv('./results/BC_peaklength.csv')
print(len(contur_height))
print(len(half_peak_res[0]))
print(type(half_peak_res))
print(type(full_peak_res))
print(type(HWpeak))
print(type(FWpeak))
print(type(contur_height))
# Out:
# Height of peaks: [2.17216081 1.96730604 1.53757952 0.85966357 1.31698079 0.979038
#  1.02656734 0.82896565 1.37486404 0.8641755  1.12626611 1.16988038
#  1.12771302 1.24925846 3.09105889 0.81564876 1.21870672 0.66179837
#  1.06395657 1.36219625 1.27440344 0.42733203 1.76831135 1.18983993
#  1.09004023 1.18301074 1.09427978 1.22218544 1.08651645 1.91421027
#  1.41596378 1.16568527 1.35207552 1.50006428 0.48509662 0.90951901
#  1.0303922  1.17884704 0.85631053 1.56711577 1.1071068  1.56417223
#  2.24148928 2.45187408 0.26137533 4.20621501 2.6307049  1.40700476
#  1.28057848 1.31436078 1.54786078 0.9961234  1.00412035 1.27770121
#  0.76909703 1.26122892 1.34629617 1.09481023 1.4970193  1.49967338
#  1.48614207 1.51116611 1.62035892 1.67432223 1.76739047 0.602153
#  2.17795838 1.4429083  1.40016657 1.23892514 1.14555591 1.40665892
#  0.94933674 1.00155212 1.27940866 1.28484241 1.59892205 1.96151738
#  1.94137805 2.33610811 0.50217004 2.64342091 2.54653516 1.93604498
#  1.63200569 1.30183371 0.35550404 1.3070618  0.94682311 1.18143748
#  1.17959021 1.0656927  0.72401966 1.28024303 1.18628848 1.27872114
#  1.08408616 1.51661343 0.36729624 0.94422174 1.15935893 1.16371972
#  1.43787655 1.19353524 1.10270914 1.27105449 1.36607116 1.6980895
#  0.75886306 1.51126315 1.01704045 1.13384235 1.63231844 1.10720206
#  1.0094125  0.84615187 1.00573055 1.19930083 1.03230657 0.89691038
#  0.74354528 0.93760392 0.94222453 0.87663676 1.53522404 1.47651561
#  1.13625459 1.03269366 0.97794672 1.99695516 0.73837299 1.00428541
#  0.70457043 1.40857567 1.18759853 0.76817305 1.24425074 0.73860409
#  4.31536766 1.19944851 1.39452542 1.47778276 1.15865817 1.10881879
#  1.10584837 1.05974778 0.92582314 1.13806486 1.04563828 0.53002414
#  3.66929979 1.75423281 1.44995183 1.14918042 1.02790269 1.31478679
#  0.82565577 0.659344   1.25354796 1.03260703 1.24671963 1.12883245
#  1.07326129 0.85876189 1.08941622 1.07372627 0.94911198 1.48188932
#  1.27504801 1.31777602 0.9845916  0.98659625 0.97921565 1.00978291
#  1.70925283 0.83986093 1.58902462 0.98283948 0.93819997 1.39033856
#  1.38678508 1.13348576 1.38940571 1.1818827  1.28113167 0.54142431
#  1.00577233 1.54963749 1.00145091 1.61366506 1.20606931 1.49823158
#  1.1029043  1.16951279 0.94097134 1.6148278  2.1360205  0.70619528
#  1.31388465 1.11905293 0.99416287 0.86417751 1.46858337 1.49162614]
# 204
# 204
# <class 'tuple'>
# <class 'tuple'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# A6sf=A6
# A6sf.shape
x1_array = peak_date2
# # # amp1 = 3000
# # # sigma1 = 10
# # # cen1 = 50
y1_array= peak_sig2
# plt.plot(x1_array, y1_array)

# %%
peaks, properties = find_peaks(y1_array, prominence=10, width=30)
sig_peaks, _ = signal.find_peaks(y1_array)
promin = signal.peak_prominences(y1_array, sig_peaks)[0]
print(len(promin))
# promin
plt.plot(promin)
# Out:
# 3655

# %%
half_peak_res = signal.peak_widths(y1_array, sig_peaks, rel_height = 0.5)
full_peak_res = signal.peak_widths(y1_array, sig_peaks, rel_height = 1)


plt.plot(x1_array, y1_array)
plt.plot(sig_peaks, y1_array[sig_peaks], "*", color = 'red')
contur_height = y1_array[sig_peaks] - promin
# plt.plot(y_array)
# plt.plot(sig_peaks, y_array[sig_peaks], "*")
#plt.vlines(x=sig_peaks, ymin=contur_height*10, ymax=y_array[sig_peaks], 
#           color ='black', linestyle='dotted')
plt.hlines(*half_peak_res[1:], color = 'C12')
plt.hlines(*full_peak_res[1:], color = 'C3')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(100))
plt.xticks(rotation =60)
plt.savefig('./results/full_BC_peak_area_height.png')
plt.show()

# %%
# print('Half width of peaks:', half_peak_res[0])
HWpeak = np.asarray(half_peak_res)
HWpeak_BC = pd.DataFrame(HWpeak)
# print(HWpeak_BC.head(3))
HWpeak_BC.to_csv('./results/full_BC_HWpeak.csv')

# print('Full width of peaks:', full_peak_res[0])
FWpeak = np.asarray(full_peak_res)
FWpeak_BC = pd.DataFrame(FWpeak)
FWpeak_BC.to_csv('./results/full_BC_FWpeak.csv')
print('Height of peaks:',contur_height)
contur_height_BC = pd.DataFrame(contur_height)
contur_height_BC.to_csv('./results/full_BC_peak_height.csv')
# contur_height.to_csv('./results/BC_peaklength.csv')
print(len(contur_height))
print(len(half_peak_res[0]))
print(type(half_peak_res))
print(type(full_peak_res))
print(type(HWpeak))
print(type(FWpeak))
print(type(contur_height))
# Out:
# Height of peaks: [2.17216081 1.96730604 1.53757952 ... 1.18428162 1.53904674 1.76935346]
# 3655
# 3655
# <class 'tuple'>
# <class 'tuple'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
